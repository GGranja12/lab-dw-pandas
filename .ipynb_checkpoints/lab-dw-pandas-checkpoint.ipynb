# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
# Your code here

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")

# %%
df.shape #dimension of the dataset (rows, columns)
# Out:
# (4008, 11)

# %%
df2 = df.copy()

# %%
df2.columns = [column.lower().replace(" ","_") for column in df2.columns]

# %%
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
#Regarding data types I spot 2 innapropriate data types as follows:
#Customer Lifetime Value should be float64 - money value
#Number of Open Complaints should be int64

# %%
df2['customer_lifetime_value'] = df2['customer_lifetime_value'].astype(float)
df2['number_of_open_complaints'] = df2['number_of_open_complaints'].astype(int) #tried to convert thes 2 series into float an integers respectively but did not manage to fix the error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2['customer_lifetime_value'] = df2['customer_lifetime_value'].astype(float)
#       2 df2['number_of_open_complaints'] = df2['number_of_open_complaints'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df2.nunique() #number of unique values per variable
# Out:
# customer                     1071
# st                              8
# gender                          5
# education                       6
# customer_lifetime_value      1027
# income                        774
# monthly_premium_auto          132
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount            761
# dtype: int64

# %%
#Usually, categorical data is characterized by a short amount of unique values. However, once interpreting the data, we must consider customer as a categprical varible given that it is an identifier for each client.
#On the other hand number_of_open_complaints must be considered as a quantitative variable that can be measured accordingly.
categorical_vars = ["customer", "st", "gender","education","policy_type", "vehicle_class"]
df2[categorical_vars]
# Out:
#      customer          st gender             education     policy_type  \
# 0     RB50392  Washington    NaN                Master   Personal Auto
# 1     QZ44356     Arizona      F              Bachelor   Personal Auto
# 2     AI49188      Nevada      F              Bachelor   Personal Auto
# 3     WW63253  California      M              Bachelor  Corporate Auto
# 4     GA49547  Washington      M  High School or Below   Personal Auto
# ...       ...         ...    ...                   ...             ...
# 4003      NaN         NaN    NaN                   NaN             NaN
# 4004      NaN         NaN    NaN                   NaN             NaN
# 4005      NaN         NaN    NaN                   NaN             NaN
# 4006      NaN         NaN    NaN                   NaN             NaN
# 4007      NaN         NaN    NaN                   NaN             NaN
#
#       vehicle_class
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# ...

# %%
df2["customer"].unique() #nominal variable
# Out:
# array(['RB50392', 'QZ44356', 'AI49188', ..., 'CW49887', 'MY31220', nan],
#       dtype=object)

# %%
df2["st"].unique() #nominal variable
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
df2["gender"].unique() #nominal variable
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
df2["education"].unique() #ordinal variable
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
df2["policy_type"].unique() #ordinal variable
# Out:
# array(['Personal Auto', 'Corporate Auto', 'Special Auto', nan],
#       dtype=object)

# %%
df2["vehicle_class"].unique() #nominal variable
# Out:
# array(['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car', nan], dtype=object)

# %%
numerical_vars = ["customer_lifetime_value","income","monthly_premium_auto", "number_of_open_complaints", "total_claim_amount"]
df2[numerical_vars]
# Out:
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number_of_open_complaints  total_claim_amount
# 0                       1/0/00            2.704934
# 1                       1/0/00         1131.464935
# 2                       1/0/00          566.472247
# ...

# %%
df2["customer_lifetime_value"].unique() #continuous variable
# Out:
# array([nan, '697953.59%', '1288743.17%', ..., '2031499.76%', '323912.47%',
#        '899704.02%'], dtype=object)

# %%
df2["income"].unique() #continuous variable
# Out:
# array([    0., 48767., 36357., 62902., 55350., 14072., 28812., 77026.,
#        99845., 83689., 24599., 25049., 28855., 51148., 66140., 57749.,
#        61040., 17870., 97541., 29723., 86584., 75690., 23158., 65999.,
#        37260., 68987., 42305., 65706., 53243., 50071., 60021., 43244.,
#        46896., 10105., 23218., 24804., 33190., 36014., 67163., 16701.,
#        46623., 64749., 16969., 11621., 17622., 11489., 66525., 33663.,
#        22547., 61486., 29879., 93011., 65186., 26840., 75644., 38984.,
#        71811., 20961., 41275., 61321., 51066., 34378., 43072., 25222.,
#        77552., 23091., 48269., 32720., 20396., 21513., 80744., 52822.,
#        69738., 17780., 18107., 57740., 32627., 65795., 60475., 41837.,
#        32303., 40531., 79898., 56398., 71600., 27804., 45506., 99428.,
#        20993., 37839., 92711., 74665., 61108., 46833., 88768., 28262.,
#        33555., 42780., 58850., 21880., 25251., 25317., 24188., 41611.,
# ...

# %%
df2["monthly_premium_auto"].unique() #continuous variable
# Out:
# array([ 1000.,    94.,   108.,   106.,    68.,    69.,    67.,   101.,
#           71.,    93.,   110.,    70.,    64.,    72.,    74.,    79.,
#           73.,    61.,   111.,    80.,    63.,   237.,    65.,   130.,
#           62.,   117.,    91.,    90.,    66.,    99.,   103., 35354.,
#          172.,    92.,   104.,   113.,   124.,   105.,   100.,   112.,
#           97.,    95.,   102.,    96.,   186.,    77.,    76.,   119.,
#           87.,   109.,   107.,    88.,    85.,  6464.,   133.,    86.,
#           78.,    89.,   192.,   118.,   140.,   127.,   126.,    82.,
#          115.,   217.,   114.,   138.,    81.,   255.,   150.,   123.,
#          116.,   190.,    98.,   159.,    84.,    83.,   152.,   136.,
#          245.,   135.,  1005.,   225.,   132.,   153.,   121.,   139.,
#          154.,   161.,   156.,   171.,   244.,   183.,   176.,   230.,
#          129.,   177.,   181.,   196.,   131.,   276.,   253.,   137.,
# ...

# %%
df2["number_of_open_complaints"].unique() #continuous variable
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan],
#       dtype=object)

# %%
df2["total_claim_amount"].unique() #continuous variable
# Out:
# array([2.70493400e+00, 1.13146493e+03, 5.66472247e+02, 5.29881344e+02,
#        1.72693230e+01, 1.59383042e+02, 3.21600000e+02, 3.63029680e+02,
#        5.11200000e+02, 4.25527834e+02, 4.82400000e+02, 5.28000000e+02,
#        4.72029737e+02, 3.07139132e+02, 4.29202710e+01, 4.54245098e+02,
#        6.47442031e+02, 3.08981664e+02, 4.84800000e+02, 3.55200000e+02,
#        2.03828760e+01, 5.54376763e+02, 4.39200000e+02, 3.89185006e+02,
#        7.99200000e+02, 2.09851050e+01, 5.32800000e+02, 3.84000000e+02,
#        3.22294043e+02, 6.15927769e+02, 3.08150890e+02, 2.38201580e+01,
#        1.54376810e+01, 2.04475147e+02, 5.61600000e+02, 4.36800000e+02,
#        6.48000000e+02, 1.57397849e+02, 4.84318536e+02, 1.89189350e+01,
#        8.82871945e+02, 4.94400000e+02, 3.17073170e+01, 5.17753000e-01,
#        5.79165954e+02, 4.47793440e+02, 5.29624084e+02, 3.13023175e+02,
#        5.93830288e+02, 5.08800000e+02, 1.73956072e+02, 3.31928030e+01,
# ...

# %%
df2[numerical_vars].describe() #it is failing to describing customer_lifetime_value and number_of_open_complaints because they are considered to be objects and I did not manage to change its type
# Out:
#              income  monthly_premium_auto  total_claim_amount
# count   1071.000000           1071.000000         1071.000000
# mean   39295.701214            193.234360          404.986909
# std    30469.427060           1601.190369          293.027260
# min        0.000000             61.000000            0.382107
# 25%    14072.000000             68.000000          202.157702
# 50%    36234.000000             83.000000          354.729129
# 75%    64631.000000            109.500000          532.800000
# max    99960.000000          35354.000000         2893.239678

# %%
for column in categorical_vars:
    print(df2[column].value_counts())
# Out:
# customer
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: count, Length: 1071, dtype: int64
# st
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64
# gender
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: count, dtype: int64
# education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: count, dtype: int64
# policy_type
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: count, dtype: int64
# vehicle_class
# Four-Door Car    576
# Two-Door Car     205
# SUV              199
# Sports Car        57
# Luxury SUV        20
# ...

# %%
#Among the valid inputs:
#Most of the customers owns a four-door car and a personal auto policytype;
#52,6% of the customers are female

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
frequency_locations = df2["st"].value_counts().tail(5)

# %%
frequency_locations
# Out:
# st
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64

# %%
type(frequency_locations)
# Out:
# pandas.core.series.Series

# %%
frequency_locations.sort_values
# Out:
# <bound method Series.sort_values of st
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64>

# %% [markdown]
# ### Exercise 2
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
policies_sold = df2["policy_type"].value_counts() #to get total number of policies sold for each type of policy

# %%
policies_sold
# Out:
# policy_type
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: count, dtype: int64

# %%
policies_sold.idxmax() #method to get he policy type with the highest number of policies sold
# Out:
# 'Personal Auto'

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know if customers with Personal Auto have a lower income than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
personal_auto_df = df2.loc[df2["policy_type"] == "Personal Auto"] #filtering by policy_type equal to Personal Auto
personal_auto_df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1065  XD85577        Cali      M              Bachelor
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1070  MY31220  California      F               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
personal_auto_df["income"].mean() #average income for personal auto
# Out:
# 38180.69871794872

# %%
corporate_auto_df = df2.loc[df2["policy_type"] == "Corporate Auto"] #filtering by policy_type equal to Corporate Auto
corporate_auto_df
# Out:
#      customer          st gender             education  \
# 3     WW63253  California      M              Bachelor
# 6     XZ87318      Oregon      F               College
# 7     CF85061     Arizona      M                Master
# 8     DY87989      Oregon      M              Bachelor
# 12    DP39365  California    NaN                Master
# ...       ...         ...    ...                   ...
# 1045  WZ31900      Oregon      F              Bachelor
# 1050  BJ53923     Arizona      M  High School or Below
# 1052  FB23788      Oregon      M  High School or Below
# 1056  PI47776      Oregon      F              Bachelor
# 1059  YG44474      Oregon      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 3                 764586.18%      0.0                 106.0
# 6                 538089.86%  55350.0                  67.0
# 7                 721610.03%      0.0                 101.0
# ...

# %%
corporate_auto_df["income"].mean() #average income for corporate auto
# Out:
# 41390.31196581197

# %% [markdown]
# ### Bonus: Exercise 4

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
df2["total_claim_amount"].describe() #used this method to get the value for the 75th percentile
# Out:
# count    1071.000000
# mean      404.986909
# std       293.027260
# min         0.382107
# 25%       202.157702
# 50%       354.729129
# 75%       532.800000
# max      2893.239678
# Name: total_claim_amount, dtype: float64

# %%
worst_total_claim_amount_df = df2.loc[df2["total_claim_amount"] > 532.800000] #I used loc to filter data after knowing the value of the 75th percentile

# %%
worst_total_claim_amount_df
# Out:
#      customer          st gender education customer_lifetime_value   income  \
# 1     QZ44356     Arizona      F  Bachelor              697953.59%      0.0
# 2     AI49188      Nevada      F  Bachelor             1288743.17%  48767.0
# 17    OE15005        Cali    NaN   College              394524.16%  28855.0
# 23    TZ98966      Nevada    NaN  Bachelor              245019.10%      0.0
# 26    US89481  California    NaN  Bachelor              394637.21%      0.0
# ...       ...         ...    ...       ...                     ...      ...
# 1059  YG44474      Oregon      M   College             1401472.13%  54193.0
# 1061  RY92647        Cali      F  Bachelor             1050677.17%      0.0
# 1068  GS98873     Arizona      F  Bachelor              323912.47%  16061.0
# 1069  CW49887  California      F    Master              462680.11%  79487.0
# 1070  MY31220  California      F   College              899704.02%  54230.0
#
# ...

# %%
worst_total_claim_amount_df.describe() #again it only assumes these variables as numerical given that I could not change the type
# Out:
#              income  monthly_premium_auto  total_claim_amount
# count    264.000000            264.000000          264.000000
# mean   23677.344697            165.193182          782.228263
# std    27013.483721            623.930992          292.751640
# min        0.000000             63.000000          537.600000
# 25%        0.000000             99.000000          606.521741
# 50%    18807.000000            114.000000          679.597985
# 75%    42423.750000            133.250000          851.400000
# max    99316.000000          10202.000000         2893.239678

# %%
for column in categorical_vars:
    print(worst_total_claim_amount_df[column].value_counts()) #using the previously defined categorical data to get insights from the worst 25% customers regaring total_claim_amount
# Out:
# customer
# QZ44356    1
# JS43228    1
# RA68844    1
# TC14209    1
# ED50963    1
#           ..
# DP84567    1
# ZF84449    1
# EM29359    1
# SF57173    1
# MY31220    1
# Name: count, Length: 264, dtype: int64
# st
# Oregon        90
# California    65
# Arizona       40
# Nevada        29
# Cali          21
# WA            10
# AZ             9
# Name: count, dtype: int64
# gender
# F         115
# M         100
# Male       16
# female      5
# Femal       2
# Name: count, dtype: int64
# education
# Bachelor                85
# High School or Below    85
# College                 82
# Master                   8
# Doctor                   4
# Name: count, dtype: int64
# policy_type
# Personal Auto     191
# Corporate Auto     60
# Special Auto       13
# Name: count, dtype: int64
# vehicle_class
# SUV              101
# Four-Door Car     69
# Two-Door Car      33
# Sports Car        31
# Luxury SUV        19
# Luxury Car        11
# Name: count, dtype: int64
